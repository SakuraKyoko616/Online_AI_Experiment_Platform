# %%
Please copy your result and paste here with your Studend ID

# %% [markdown]
# ![image.png](attachment:image.png) Student ID: 34180761
