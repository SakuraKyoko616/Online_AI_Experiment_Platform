# %% [markdown]
# Welcome to Machine Learning:Logistic Refression Classifier Lab!

# %%
import matplotlib.pyplot as plot
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.inspection import DecisionBoundaryDisplay

# %% [markdown]
# This part imports necessary libraries that will be used in the following experiment.

# %%
dataset = datasets.load_iris()
X = dataset.data[:, :2] 
Y = dataset.target

# %% [markdown]
# This part we load a dataset called iris from sklearn, and we print the shape of it.

# %%
LogisticRegression = LogisticRegression(C=1)
LogisticRegression.fit(X, Y)
# Out:
# LogisticRegression(C=1)

# %% [markdown]
# Here, we define a variable called LogisticRegression and assign it with the algorithm LogisticRegression with the defalut parameter C=1. Then we train this model.
# You are suopposed to change the value of C and study how the decision boundary changes.

# %%
fig, ax = plot.subplots(figsize=(4, 4))

DecisionBoundaryDisplay.from_estimator(
    LogisticRegression,
    X,
    ax=ax,
    response_method="auto",
    plot_method="pcolormesh",
    xlabel="sepal length",
    ylabel="sepal width",
)

plot.scatter(X[:, 0], X[:, 1], c=Y, edgecolors="k")
plot.show()

# %% [markdown]
# This code displays the output (decision boundary) of LR with pyplot
